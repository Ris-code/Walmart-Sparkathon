# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.0.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 325.1 kB/s eta 0:00:36
#    ---------------------------------------- 0.0/11.6 MB 325.1 kB/s eta 0:00:36
#    ---------------------------------------- 0.0/11.6 MB 325.1 kB/s eta 0:00:36
#    ---------------------------------------- 0.0/11.6 MB 325.1 kB/s eta 0:00:36
#    ---------------------------------------- 0.0/11.6 MB 325.1 kB/s eta 0:00:36
#    ---------------------------------------- 0.0/11.6 MB 98.1 kB/s eta 0:01:59
#    ---------------------------------------- 0.1/11.6 MB 136.5 kB/s eta 0:01:25
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df1 = df[["product_name", "category", "discounted_price", "actual_price", "discount_percentage", "rating", "rating_count", "review_title", "review_content", "about_product"]]
df1
# Out:
#                                            product_name  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     Sounce Fast Phone Charging Cable & Data Sync U...
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                 ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
df1.to_csv('product.csv')

# %%
df1 = pd.read_csv('product.csv')
df1
# Out:
#       Unnamed: 0                                       product_name  \
# 0              0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1              1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2              2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3              3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4              4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460        1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461        1461  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462        1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463        1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464        1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#   Using cached langchain_community-0.2.12-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached langsmith-0.1.99-py3-none-any.whl.metadata (13 kB)
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 196.9 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 232.0 kB/s eta 0:00:00
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached aiohappyeyeballs-2.3.5-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

link = "https://www.walmart.com/help/article/track-your-order/143cf6e1d8cb48e6a1ed840409881235"
loader = WebBaseLoader(link)
data = loader.load()
print(data)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 link = "https://www.walmart.com/help/article/track-your-order/143cf6e1d8cb48e6a1ed840409881235"
#       4 loader = WebBaseLoader(link)
# ----> 5 data = loader.load()
#       6 print(data)
#
# File c:\Users\aichr\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\document_loaders\base.py:30, in BaseLoader.load(self)
#      28 def load(self) -> List[Document]:
#      29     """Load data into Document objects."""
# ---> 30     return list(self.lazy_load())
#
# File c:\Users\aichr\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\document_loaders\web_base.py:261, in WebBaseLoader.lazy_load(self)
#     259 """Lazy load text from the url(s) in web_path."""
# ...
