# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv(r"products.csv")

# %%
products.shape
# Out:
# (32226, 13)

# %%
sales = pd.read_csv(r"sales.csv")

# %%
sales.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0       date_  \
# 0             0        753477        753477      753477  2022-04-01
# 1             1       2990828       2990828     2990828  2022-04-15
# 2             2      27026764       4829574     4829574  2022-06-09
# 3             3      36826782       2476827     2476827  2022-05-07
# 4             4      17662591       2276695     2276695  2022-07-08
#
#    city_name   order_id    cart_id  dim_customer_key  procured_quantity  \
# 0     HR-NCR  112250867  164444739           3326530                  1
# 1      Delhi  115229870  181299552          16031366                  1
# 2  Bengaluru  129338452  206030370           1206076                  1
# 3     HR-NCR  120438889  194958751            578535                  1
# 4      Delhi  137087730  230469163          10953663                  1
#
#    unit_selling_price  total_discount_amount  product_id  \
# 0                21.0                    0.0      448913
# ...

# %%
products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0      476763                                   Christmas - Card
# 1           1      483436  Plum BodyLovin' Hawaiian Rumba Shower Gel - Sa...
# 2           2      476825                     Diwali Gift Card Free - Sample
# 3           3      483438  Plum BodyLovin' Trippin' Mimosas Shower Gel - ...
# 4           4      480473             Flipkart Valentine Day Greeting - Card
#
#      unit product_type       brand_name  \
# 0  1 unit         Card              NaN
# 1   20 ml       Sample  Plum BodyLovin'
# 2  1 unit       Sample              NaN
# 3   20 ml       Sample  Plum BodyLovin'
# 4  1 unit         Card         Flipkart
#
#                         manufacturer_name l0_category   l1_category  \
# 0                                     HOT    Specials  Bill Breaker
# 1  Pureplay Skin Sciences India Pvt. Ltd.    Specials    Free Store
# ...

# %%
merged_df = pd.merge(sales, products, on='product_id', how='inner')
merged_df.drop(columns=['Unnamed: 0.3',	'Unnamed: 0.2',	'Unnamed: 0.1', 'Unnamed: 0_x'] , inplace = True)
merged_df.to_csv('merged_sales_products.csv', index=False)

merged_df.head()
# Out:
#         date_  city_name   order_id    cart_id  dim_customer_key  \
# 0  2022-04-01     HR-NCR  112250867  164444739           3326530
# 1  2022-04-15      Delhi  115229870  181299552          16031366
# 2  2022-06-09  Bengaluru  129338452  206030370           1206076
# 3  2022-05-07     HR-NCR  120438889  194958751            578535
# 4  2022-07-08      Delhi  137087730  230469163          10953663
#
#    procured_quantity  unit_selling_price  total_discount_amount  product_id  \
# 0                  1                21.0                    0.0      448913
# 1                  1               105.0                    0.0        3570
# 2                  1                46.0                    0.0      432778
# 3                  1                30.0                    0.0       86446
# 4                  1                30.0                    0.0      123060
#
#    total_weighted_landing_price  ...                     unit  product_type  \
# ...
